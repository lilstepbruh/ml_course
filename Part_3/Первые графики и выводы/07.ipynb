# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %store -r df

# %%
df['time_spent'].hist(bins=100, range=(0,1100))
# Out:
# <Axes: >

# %%
df.boxplot(column='time_spent')
# Out:
# <Axes: >

# %%
plt.ylim(-100,1000)
plt.boxplot(df['time_spent']);
