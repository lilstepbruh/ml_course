# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn import metrics

# %%
data = pd.read_csv("/home/stepbruh/Рабочий стол/Практикум/Специалист по Data Science Плюс. Часть 11 из 16/05 Градиентный бустинг/travel_insurance.csv")

data['Gender'] = data.Gender.fillna('unknown')

features_train, features_valid, target_train, target_valid = train_test_split(
    data.drop('Claim', axis=1), data.Claim, test_size=0.25, random_state=12345)

cat_features = ['Agency', 'Agency Type', 'Distribution Channel',
                'Product Name', 'Destination', 'Gender']

model = CatBoostClassifier(iterations=250)

model.fit(features_train, target_train, cat_features=cat_features)

probabilities_valid = model.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]
print(metrics.roc_auc_score(target_valid, probabilities_one_valid))
# Out:
# Learning rate set to 0.173607
# 0:	learn: 0.3910472	total: 14.8ms	remaining: 3.68s
# 1:	learn: 0.2408767	total: 24.6ms	remaining: 3.05s
# 2:	learn: 0.1623438	total: 41ms	remaining: 3.37s
# 3:	learn: 0.1248938	total: 49.5ms	remaining: 3.05s
# 4:	learn: 0.1032590	total: 65ms	remaining: 3.18s
# 5:	learn: 0.0914873	total: 82ms	remaining: 3.33s
# 6:	learn: 0.0820198	total: 94.5ms	remaining: 3.28s
# 7:	learn: 0.0760555	total: 113ms	remaining: 3.42s
# 8:	learn: 0.0739274	total: 120ms	remaining: 3.22s
# 9:	learn: 0.0712561	total: 137ms	remaining: 3.29s
# 10:	learn: 0.0705554	total: 143ms	remaining: 3.11s
# 11:	learn: 0.0692008	total: 159ms	remaining: 3.15s
# 12:	learn: 0.0681919	total: 176ms	remaining: 3.21s
# 13:	learn: 0.0674945	total: 194ms	remaining: 3.27s
# 14:	learn: 0.0670727	total: 214ms	remaining: 3.35s
# 15:	learn: 0.0668005	total: 231ms	remaining: 3.37s
# 16:	learn: 0.0663985	total: 246ms	remaining: 3.37s
# 17:	learn: 0.0662040	total: 266ms	remaining: 3.43s
# ...
